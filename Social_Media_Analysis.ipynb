# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read instagram
insta = pd.read_csv('./Clean_Data/merged_instagram_data_cleaned.csv')

# read tiktok
tiktok = pd.read_csv('./Clean_Data/merged_tiktok_data_cleaned.csv')

# read youtube
youtube = pd.read_csv('./Clean_Data/merged_youtube_data_cleaned.csv')

# %%
insta
# Out:
#         sno      instagram_name               name  subscribers  \
# 0       1.0           cristiano  Cristiano Ronaldo            0
# 1       2.0         kyliejenner            Kylie 🤍            0
# 2       3.0        arianagrande      Ariana Grande            0
# 3       4.0            leomessi          Leo Messi            0
# 4       5.0             zendaya            Zendaya            0
# ...     ...                 ...                ...          ...
# 4928  512.5             zendaya                NaN            0
# 4929  512.5              zidane                NaN            0
# 4930  512.5              zkdlin                NaN            0
# 4931  512.5                  zo                NaN            0
# 4932  512.5  zoeisabellakravitz                NaN            0
#
#      audience_country authentic_engagement engagement_average  \
# 0               India                   5M               6.2M
# 1       United States                 3.5M               5.5M
# ...

# %%
tiktok
# Out:
#         sno    tiktoker_name       tiktok_name  subscribers  views_avg  \
# 0       1.0    jypestraykids        Stray Kids            0        0.0
# 1       2.0       khaby.lame      Khabane lame            0        0.0
# 2       3.0   scarlettsspam2          scarlett            0        0.0
# 3       4.0        addisonre       Addison Rae            0        0.0
# 4       5.0       belindatok           Belinda            0        0.0
# ...     ...              ...               ...          ...        ...
# 3981  500.0  nathanmccarron0      Nathan’s Art            0        0.0
# 3982  500.0        lacha21.1   Lazaro Gonzalez            0        0.0
# 3983  500.0          hyoga.x             Hyoga            0        0.0
# 3984  500.0   rrqr7tatsumaki    Rivaldi Fataah            0        0.0
# 3985  500.0         _catben_  Catherine Benson            0        0.0
#
#       likes_avg  comments_avg  shares_avg subscribers_count   rank  ...  \
# ...

# %%
youtube
# Out:
#          sno  name               youtuber_name audience_country  subscribers  \
# 0        1.0   NaN                    T-Series          Unknown            0
# 1        2.0   NaN                   SET India          Unknown            0
# 2        3.0   NaN  Cocomelon - Nursery Rhymes          Unknown            0
# 3        4.0   NaN                     MrBeast          Unknown            0
# 4        5.0   NaN                   PewDiePie          Unknown            0
# ...      ...   ...                         ...              ...          ...
# 1967   996.0   NaN                        RUOK          Unknown            0
# 1968   997.0   NaN                    Fox News          Unknown            0
# 1969   998.0   NaN            SULE PRODUCTIONS          Unknown            0
# 1970   999.0   NaN                     MBCkpop          Unknown            0
# 1971  1000.0   NaN               Dynamo Gaming          Unknown            0
#
# ...

# %%
# --- Analysis for merged_instagram_df ---
print("\n--- Analyzing merged_instagram_df ---")

# Basic Descriptive Statistics
print("\nDescriptive Statistics:")
print(insta.describe(include='all'))

# Top 10 by Subscribers
if 'subscribers' in insta.columns:
    top_10_insta_subscribers = insta.sort_values(by='subscribers', ascending=False).head(10)
    print("\nTop 10 by Subscribers:")
    print(top_10_insta_subscribers[['instagram_name', 'subscribers']].fillna('N/A'))

    if 'subscribers' in insta.columns:
        top_10_insta_subscribers = insta.sort_values(by='subscribers', ascending=False).head(10)
        print("\nTop 10 by Subscribers:")
        print(top_10_insta_subscribers[['instagram_name', 'subscribers']].fillna('N/A'))

        plt.figure(figsize=(10, 6))
        sns.barplot(x='subscribers', y=top_10_insta_subscribers['instagram_name'].fillna('N/A'), data=top_10_insta_subscribers, palette='viridis') # Explicitly pass data
        plt.title('Top 10 Instagram by Subscribers')
        plt.xlabel('Subscribers')
        plt.ylabel('Instagram Name')
        plt.tight_layout()
        plt.show()

# Distribution of Subscribers
if 'subscribers' in insta.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(insta['subscribers'], bins=50, kde=True)
    plt.title('Distribution of Instagram Subscribers')
    plt.xlabel('Subscribers')
    plt.ylabel('Frequency')
    plt.show()

# Average Engagement
engagement_cols_insta = [col for col in insta.columns if 'engagement' in col]
if engagement_cols_insta:
    print("\nAverage Engagement Metrics:")
    print(insta[engagement_cols_insta].mean())

    plt.figure(figsize=(8, 5))
    insta[engagement_cols_insta].mean().plot(kind='bar')
    plt.title('Average Engagement Metrics on Instagram')
    plt.ylabel('Average Value')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

# Top Categories (Category 1)
if 'category_1' in insta.columns and insta['category_1'].nunique() > 1:
    top_insta_categories = insta['category_1'].value_counts().nlargest(10)
    print("\nTop 10 Category 1:")
    print(top_insta_categories)

    plt.figure(figsize=(10, 6))
    sns.barplot(x=top_insta_categories.index, y=top_insta_categories.values, palette='plasma')
    plt.title('Top 10 Instagram Category 1')
    plt.xlabel('Category')
    plt.ylabel('Number of Influencers')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# --- Analyzing merged_instagram_df ---
#
# Descriptive Statistics:
#                 sno instagram_name     name  subscribers audience_country  \
# count   4933.000000           4933     2938       4933.0             1976
# unique          NaN           2604     2143          NaN               37
# top             NaN     marshmello  davikah          NaN    United States
# freq            NaN              6        3          NaN              549
# mean     507.665214            NaN      NaN          0.0              NaN
# std      182.917452            NaN      NaN          0.0              NaN
# min        1.000000            NaN      NaN          0.0              NaN
# 25%      512.500000            NaN      NaN          0.0              NaN
# 50%      512.500000            NaN      NaN          0.0              NaN
# 75%      512.500000            NaN      NaN          0.0              NaN
# max     1000.000000            NaN      NaN          0.0              NaN
#
# ...

# %%
print("\n--- Analyzing merged_tiktok_df ---")

# Basic Descriptive Statistics
print("\nDescriptive Statistics:")
print(tiktok.describe(include='all'))

# Top 10 by Subscribers
if 'subscribers' in tiktok.columns:
    top_10_tiktok_subscribers = tiktok.sort_values(by='subscribers', ascending=False).head(10)
    print("\nTop 10 by Subscribers:")
    print(top_10_tiktok_subscribers[['tiktok_name', 'subscribers']].fillna('N/A'))

    plt.figure(figsize=(10, 6))
    sns.barplot(x='subscribers', y=top_10_tiktok_subscribers['tiktok_name'].fillna('N/A'), palette='viridis')
    plt.title('Top 10 TikTok by Subscribers')
    plt.xlabel('Subscribers')
    plt.ylabel('TikTok Name')
    plt.tight_layout()
    plt.show()

# Distribution of Subscribers
if 'subscribers' in tiktok.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(tiktok['subscribers'], bins=50, kde=True)
    plt.title('Distribution of TikTok Subscribers')
    plt.xlabel('Subscribers')
    plt.ylabel('Frequency')
    plt.show()

# Average Engagement
engagement_cols_tiktok = [col for col in tiktok.columns if 'engagement' in col]
if engagement_cols_tiktok:
    print("\nAverage Engagement Metrics:")
    print(tiktok[engagement_cols_tiktok].mean())
    
    plt.figure(figsize=(8, 5))
    tiktok[engagement_cols_tiktok].mean().plot(kind='bar')
    plt.title('Average Engagement Metrics on TikTok')
    plt.ylabel('Average Value')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# --- Analyzing merged_tiktok_df ---
#
# Descriptive Statistics:
#                 sno tiktoker_name tiktok_name  subscribers  views_avg  \
# count   3986.000000          3986        3986       3986.0     3986.0
# unique          NaN          2625        2677          NaN        NaN
# top             NaN   brookemonk_    Fernanda          NaN        NaN
# freq            NaN             5           7          NaN        NaN
# mean     500.117662           NaN         NaN          0.0        0.0
# std      144.608227           NaN         NaN          0.0        0.0
# min        1.000000           NaN         NaN          0.0        0.0
# 25%      500.000000           NaN         NaN          0.0        0.0
# 50%      500.000000           NaN         NaN          0.0        0.0
# 75%      500.000000           NaN         NaN          0.0        0.0
# max     1000.000000           NaN         NaN          0.0        0.0
#
# ...
