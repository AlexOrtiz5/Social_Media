# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Load all of the CSV files

# %% [markdown]
# All the names of the files:
# 1. social media influencers - instagram sep-2022
# 2. social media influencers - instagram
# 3. social media influencers - Tiktok sep 2022
# 4. social media influencers - tiktok
# 5. social media influencers - Youtube sep-2022
# 6. social media influencers - youtube
# 7. social media influencers-INSTAGRAM - -DEC 2022
# 8. social media influencers-instagram - -nov 2022
# 9. social media influencers-instagram june 2022 - june 2022
# 10. social media influencers-TIKTOK - ---DEC 2022
# 11. social media influencers-tiktok - ---nov 2022
# 12. social media influencers-tiktok june 2022 - june 2022
# 13. social media influencers-YOUTUBE - --DEC 2022
# 14. social media influencers-youtube - --nov 2022
# 15. social media influencers-youtube june 2022 - june 2022

# %% [markdown]
# # First file to Clean

# %%
df1 = pd.read_csv("./Media_Data/social media influencers - instagram sep-2022.csv") 
df1
# Out:
#       S.no  Instagram name                   Name Subscribers  \
# 0        1       cristiano      Cristiano Ronaldo      477.9M
# 1        2     kyliejenner                Kylie 🤍      368.1M
# 2        3    arianagrande          Ariana Grande      329.6M
# 3        4        leomessi              Leo Messi      358.6M
# 4        5         zendaya                Zendaya      151.1M
# ...    ...             ...                    ...         ...
# 1045   996   jadethirlwall  jade amelia thirlwall        9.4M
# 1046   997           ninja         User Not Found       12.9M
# 1047   998     myriamfares           Myriam Fares       20.6M
# 1048   999    optimushwang                    황민현        4.2M
# 1049  1000  syifahadjureal            Syifa Hadju       15.5M
#
#      Audience country Authentic engagement\n Engagement average\r\n  \
# 0               India                     5M                   6.2M
# 1       United States                   3.5M                   5.5M
# ...

# %%
df1.columns
# Out:
# Index(['S.no', 'Instagram name', ' Name', 'Subscribers', 'Audience country',
#        'Authentic engagement\n', 'Engagement average\r\n', 'Category_1',
#        'Category_2'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df1.columns = df1.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df1.columns = df1.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace in these columns
string_columns = df1.select_dtypes(include='object').columns
for col in string_columns:
    df1[col] = df1[col].str.strip()
    
df1
# Out:
#       s.no  instagram_name                   name subscribers  \
# 0        1       cristiano      Cristiano Ronaldo      477.9M
# 1        2     kyliejenner                Kylie 🤍      368.1M
# 2        3    arianagrande          Ariana Grande      329.6M
# 3        4        leomessi              Leo Messi      358.6M
# 4        5         zendaya                Zendaya      151.1M
# ...    ...             ...                    ...         ...
# 1045   996   jadethirlwall  jade amelia thirlwall        9.4M
# 1046   997           ninja         User Not Found       12.9M
# 1047   998     myriamfares           Myriam Fares       20.6M
# 1048   999    optimushwang                    황민현        4.2M
# 1049  1000  syifahadjureal            Syifa Hadju       15.5M
#
#      audience_country authentic_engagement engagement_average  \
# 0               India                   5M               6.2M
# 1       United States                 3.5M               5.5M
# ...

# %% [markdown]
# # Second file to Clean

# %%
df2 = pd.read_csv("./Media_Data/social media influencers - instagram.csv") 
df2
# Out:
#     Influencer insta name instagram name                 category_1  \
# 0                     433            433         Sports with a ball
# 1            __youngbae__        TAEYANG                      Music
# 2             _agentgirl_  НАСТЯ ИВЛЕЕВА                      Shows
# 3             _imyour_joy            Joy                  Lifestyle
# 4           _jeongjaehyun        Jaehyun                        NaN
# ..                    ...            ...                        ...
# 995               zendaya        Zendaya  Cinema & Actors/actresses
# 996                zidane         zidane         Sports with a ball
# 997                zkdlin            KAI                      Music
# 998    zoeisabellakravitz   Zoë Kravitz  Cinema & Actors/actresses
# 999               zoesugg      Zoë Sugg                  Lifestyle
#
#              category_2 Followers Audience country(mostly)  \
# 0                   NaN     48.5M                    Spain
# ...

# %%
df2.columns
# Out:
# Index(['Influencer insta name', 'instagram name', 'category_1', 'category_2',
#        'Followers', 'Audience country(mostly)', 'Authentic engagement\r\n',
#        'Engagement avg\r\n'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df2.columns = df2.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df2.columns = df2.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace in these columns
string_columns_2 = df2.select_dtypes(include='object').columns
for col in string_columns_2:
    df2[col] = df2[col].str.strip()

# You might notice some similar columns between the two files.
# Let's try to make the naming consistent for potential merging later.
column_mapping = {
    'influencer insta name': 'influencer_insta_name',
    'instagram name': 'instagram_name',
    'followers': 'subscribers',  # Assuming 'Followers' is equivalent to 'Subscribers'
    'audience country(mostly)': 'audience_country',
    'authentic engagement\r\n': 'authentic_engagement',
    'engagement avg\r\n': 'engagement_average'
}
df2.rename(columns=column_mapping, inplace=True)
df2
# Out:
#     influencer_insta_name instagram_name                 category_1  \
# 0                     433            433         Sports with a ball
# 1            __youngbae__        TAEYANG                      Music
# 2             _agentgirl_  НАСТЯ ИВЛЕЕВА                      Shows
# 3             _imyour_joy            Joy                  Lifestyle
# 4           _jeongjaehyun        Jaehyun                        NaN
# ..                    ...            ...                        ...
# 995               zendaya        Zendaya  Cinema & Actors/actresses
# 996                zidane         zidane         Sports with a ball
# 997                zkdlin            KAI                      Music
# 998    zoeisabellakravitz   Zoë Kravitz  Cinema & Actors/actresses
# 999               zoesugg      Zoë Sugg                  Lifestyle
#
#              category_2 subscribers audience_country(mostly)  \
# 0                   NaN       48.5M                    Spain
# ...

# %% [markdown]
# # Third file to Clean

# %%
df3 = pd.read_csv("./Media_Data/social media influencers - Tiktok sep 2022.csv") 
df3
# Out:
#      S.no   Tiktoker name    Tiktok name Subscribers Views avg. Likes avg.  \
# 0       1   jypestraykids     Stray Kids       13.8M       6.4M       2.3M
# 1       2      khaby.lame   Khabane lame      149.2M      17.3M       2.3M
# 2       3  scarlettsspam2       scarlett        2.1M      17.9M     845.8K
# 3       4       addisonre    Addison Rae       88.7M        22M     906.6K
# 4       5      belindatok        Belinda        4.8M      14.2M       1.5M
# ..    ...             ...            ...         ...        ...        ...
# 995   996    brendadialoy  Brenda Dialoy      371.9K       1.2M     187.5K
# 996   997     jujufitcats   Juju Fitcats        4.3M       2.2M     280.8K
# 997   998          xoteam        XO Team       37.8M       2.5M     180.2K
# 998   999        kimsnwuo             ️️      100.9K     957.4K     226.8K
# 999  1000        jass_mcg       jass_mcg       52.2K     503.8K       116K
#
#     Comments avg. Shares avg.
# 0           50.2K       34.2K
# ...

# %%
df3.columns
# Out:
# Index(['S.no', 'Tiktoker name', 'Tiktok name', 'Subscribers', 'Views avg.',
#        'Likes avg.', 'Comments avg.', 'Shares avg.'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df3.columns = df3.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df3.columns = df3.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_3 = df3.select_dtypes(include='object').columns
for col in string_columns_3:
    df3[col] = df3[col].str.strip()

# Rename columns for potential consistency with other files
# based on your project's needs.
column_mapping_3 = {
    'tiktoker name': 'tiktoker_name',
    'tiktok name': 'tiktok_name',
    'subscribers': 'subscribers',
    'views avg.': 'views_average',
    'likes avg.': 'likes_average',
    'comments avg.': 'comments_average',
    'shares avg.': 'shares_average'
}
df3.rename(columns=column_mapping_3, inplace=True)
df3
# Out:
#      s.no   tiktoker_name    tiktok_name subscribers views_avg. likes_avg.  \
# 0       1   jypestraykids     Stray Kids       13.8M       6.4M       2.3M
# 1       2      khaby.lame   Khabane lame      149.2M      17.3M       2.3M
# 2       3  scarlettsspam2       scarlett        2.1M      17.9M     845.8K
# 3       4       addisonre    Addison Rae       88.7M        22M     906.6K
# 4       5      belindatok        Belinda        4.8M      14.2M       1.5M
# ..    ...             ...            ...         ...        ...        ...
# 995   996    brendadialoy  Brenda Dialoy      371.9K       1.2M     187.5K
# 996   997     jujufitcats   Juju Fitcats        4.3M       2.2M     280.8K
# 997   998          xoteam        XO Team       37.8M       2.5M     180.2K
# 998   999        kimsnwuo             ️️      100.9K     957.4K     226.8K
# 999  1000        jass_mcg       jass_mcg       52.2K     503.8K       116K
#
#     comments_avg. shares_avg.
# 0           50.2K       34.2K
# ...

# %% [markdown]
# # Fourth file to Clean

# %%
df4 = pd.read_csv("./Media_Data/social media influencers - tiktok.csv") 
df4
# Out:
#        Tiktoker name          Tiktok name Subscribers count Views avg.  \
# 0           ekin.721               MOMO’s            221.7K        26M
# 1            dojacat             Doja Cat             22.2M      25.4M
# 2        kiet.ac.quy           Kiệt Ắk Wỷ              2.1M      20.7M
# 3      charlidamelio      charli d’amelio            135.4M      18.7M
# 4     luvadepedreiro  Iran Ferreira (Lai)             11.4M      24.8M
# ..               ...                  ...               ...        ...
# 995    nicolebernaal        nicolebernaal                4M       2.2M
# 996    bellaretamosa                bella              5.1M       2.5M
# 997         tunico80      🌠Antonio Tonon🌠              5.8M         1M
# 998     armon.warren              Armoney              1.2M       1.9M
# 999  soanhvadiephihi       Soanh x Diệp 💎              1.6M       2.6M
#
#     Likes avg Comments avg. Shares avg
# 0        2.8M         29.4K     116.4K
# ...

# %%
df4.columns
# Out:
# Index(['Tiktoker name', 'Tiktok name', 'Subscribers count', 'Views avg.',
#        'Likes avg', 'Comments avg.', 'Shares avg'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df4.columns = df4.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df4.columns = df4.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_4 = df4.select_dtypes(include='object').columns
for col in string_columns_4:
    df4[col] = df4[col].str.strip()

# Rename columns for potential consistency
column_mapping_4 = {
    'tiktoker name': 'tiktoker_name',
    'tiktok name': 'tiktok_name',
    'subscribers count': 'subscribers',
    'views avg.': 'views_average',
    'likes avg': 'likes_average',
    'comments avg.': 'comments_average',
    'shares avg': 'shares_average'
}
df4.rename(columns=column_mapping_4, inplace=True)
df4
# Out:
#        tiktoker_name          tiktok_name subscribers_count views_avg.  \
# 0           ekin.721               MOMO’s            221.7K        26M
# 1            dojacat             Doja Cat             22.2M      25.4M
# 2        kiet.ac.quy           Kiệt Ắk Wỷ              2.1M      20.7M
# 3      charlidamelio      charli d’amelio            135.4M      18.7M
# 4     luvadepedreiro  Iran Ferreira (Lai)             11.4M      24.8M
# ..               ...                  ...               ...        ...
# 995    nicolebernaal        nicolebernaal                4M       2.2M
# 996    bellaretamosa                bella              5.1M       2.5M
# 997         tunico80      🌠Antonio Tonon🌠              5.8M         1M
# 998     armon.warren              Armoney              1.2M       1.9M
# 999  soanhvadiephihi       Soanh x Diệp 💎              1.6M       2.6M
#
#     likes_avg comments_avg. shares_avg
# 0        2.8M         29.4K     116.4K
# ...

# %% [markdown]
# # Fifth file to Clean

# %%
df5 = pd.read_csv("./Media_Data/social media influencers - Youtube sep-2022.csv") 
df5
# Out:
#       S.no                        Name           Youtuber        Country  \
# 0        1                    T-Series            tseries          India
# 1        2  Cocomelon - Nursery Rhymes          checkgate            NaN
# 2        3                   PewDiePie          PewDiePie  United States
# 3        4                     MrBeast        MrBeast6000  United States
# 4        5           ✿ Kids Diana Show  ✿ Kids Diana Show            NaN
# ...    ...                         ...                ...            ...
# 1042   996                Raditya Dika       Raditya Dika      Indonesia
# 1043   997               Ini Talk Show        IniTalkShow      Indonesia
# 1044   998               SpriteDer SPD      SpriteDer SPD       Thailand
# 1045   999             Classic Mr Bean    Classic Mr Bean          India
# 1046  1000                  Heera Gold         Heera Gold       Pakistan
#
#       Subscribers     Category_2 Avg. views\r\n Avg. likes Avg Comments  \
# ...

# %%
df5.columns
# Out:
# Index(['S.no', 'Name', 'Youtuber', 'Country', ' Subscribers', 'Category_2',
#        'Avg. views\r\n', 'Avg. likes', 'Avg Comments', 'Category_3'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df5.columns = df5.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df5.columns = df5.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_5 = df5.select_dtypes(include='object').columns
for col in string_columns_5:
    df5[col] = df5[col].str.strip()

# Rename columns for potential consistency
column_mapping_5 = {
    'name': 'name',
    'youtuber': 'youtuber_name',
    'country': 'audience_country',  # Assuming 'Country' relates to audience
    'subscribers': 'subscribers',
    'avg. views\r\n': 'views_average',
    'avg. likes': 'likes_average',
    'avg comments': 'comments_average',
    'category_2': 'category_2',
    'category_3': 'category_3'
}
df5.rename(columns=column_mapping_5, inplace=True)
df5
# Out:
#       s.no                        name      youtuber_name audience_country  \
# 0        1                    T-Series            tseries            India
# 1        2  Cocomelon - Nursery Rhymes          checkgate              NaN
# 2        3                   PewDiePie          PewDiePie    United States
# 3        4                     MrBeast        MrBeast6000    United States
# 4        5           ✿ Kids Diana Show  ✿ Kids Diana Show              NaN
# ...    ...                         ...                ...              ...
# 1042   996                Raditya Dika       Raditya Dika        Indonesia
# 1043   997               Ini Talk Show        IniTalkShow        Indonesia
# 1044   998               SpriteDer SPD      SpriteDer SPD         Thailand
# 1045   999             Classic Mr Bean    Classic Mr Bean            India
# 1046  1000                  Heera Gold         Heera Gold         Pakistan
#
# ...

# %% [markdown]
# # Sixth file to Clean

# %%
df6 = pd.read_csv("./Media_Data/social media influencers - youtube.csv") 
df6
# Out:
#     youtuber name                channel name       Category Subscribers  \
# 0         tseries                    T-Series  Music & Dance      212.1M
# 1       checkgate  Cocomelon - Nursery Rhymes      Education      132.1M
# 2        setindia                   SET India            NaN      130.4M
# 3       PewDiePie                   PewDiePie      Animation      111.4M
# 4     MrBeast6000                     MrBeast    Video games       92.5M
# ..            ...                         ...            ...         ...
# 995   FutParódias                 FutParódias  Music & Dance        9.2M
# 996       EL GATO                     EL GATO           Toys        9.2M
# 997    CinemaSins                  CinemaSins         Movies        9.2M
# 998    CricketICC                         ICC         Sports        9.2M
# 999       BRKsEDU                     BRKsEDU      Animation        9.2M
#
#     Audience Country avg views avg likes avg comments
# ...

# %%
df6.columns
# Out:
# Index(['youtuber name', 'channel name', 'Category', 'Subscribers',
#        'Audience Country', 'avg views', 'avg likes', 'avg comments'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df6.columns = df6.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df6.columns = df6.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_6 = df6.select_dtypes(include='object').columns
for col in string_columns_6:
    df6[col] = df6[col].str.strip()

# Rename columns for potential consistency
column_mapping_6 = {
    'youtuber name': 'youtuber_name',
    'channel name': 'youtube_channel_name',  # Renamed for clarity
    'category': 'category',
    'subscribers': 'subscribers',
    'audience country': 'audience_country',
    'avg views': 'views_average',
    'avg likes': 'likes_average',
    'avg comments': 'comments_average'
}
df6.rename(columns=column_mapping_6, inplace=True)
df6
# Out:
#     youtuber_name                channel_name       category subscribers  \
# 0         tseries                    T-Series  Music & Dance      212.1M
# 1       checkgate  Cocomelon - Nursery Rhymes      Education      132.1M
# 2        setindia                   SET India            NaN      130.4M
# 3       PewDiePie                   PewDiePie      Animation      111.4M
# 4     MrBeast6000                     MrBeast    Video games       92.5M
# ..            ...                         ...            ...         ...
# 995   FutParódias                 FutParódias  Music & Dance        9.2M
# 996       EL GATO                     EL GATO           Toys        9.2M
# 997    CinemaSins                  CinemaSins         Movies        9.2M
# 998    CricketICC                         ICC         Sports        9.2M
# 999       BRKsEDU                     BRKsEDU      Animation        9.2M
#
#     audience_country avg_views avg_likes avg_comments
# ...

# %% [markdown]
# # Seventh file to Clean

# %%
df7 = pd.read_csv("./Media_Data/social media influencers-INSTAGRAM - -DEC 2022.csv") 
df7
# Out:
#      Rank             name       instagram name          Category_1  \
# 0       1         leomessi            Leo Messi  Sports with a ball
# 1       2        cristiano    Cristiano Ronaldo  Sports with a ball
# 2       3         neymarjr                NJ 🇧🇷  Sports with a ball
# 3       4      kyliejenner              Kylie 🤍             Fashion
# 4       5    kendalljenner              Kendall            Modeling
# ..    ...              ...                  ...                 ...
# 995   996          thiago6     Thiago Alcantara  Sports with a ball
# 996   997  soycintiacossio        Cintia Cossio            Modeling
# 997   998        feat.dino                   이찬           Lifestyle
# 998   999       djokernole       Novak Djokovic  Sports with a ball
# 999  1000  ravindra.jadeja  Ravindrasinh jadeja           Lifestyle
#
#              Category_2 followers         country Eng. (Auth.) Eng. (Avg.)
# 0                Family    409.8M       Argentina        17.8M       23.4M
# ...

# %%
df7.columns
# Out:
# Index(['Rank', 'name', 'instagram name', 'Category_1', 'Category_2',
#        'followers', 'country', 'Eng. (Auth.)', 'Eng. (Avg.)'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df7.columns = df7.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df7.columns = df7.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_7 = df7.select_dtypes(include='object').columns
for col in string_columns_7:
    df7[col] = df7[col].str.strip()

# Rename columns for potential consistency
column_mapping_7 = {
    'name': 'name',
    'instagram name': 'instagram_name',
    'category_1': 'category_1',
    'category_2': 'category_2',
    'followers': 'subscribers',  # Assuming 'followers' is the same as 'Subscribers'
    'country': 'audience_country',  # Assuming 'country' refers to audience location
    'eng. (auth.)': 'authentic_engagement',
    'eng. (avg.)': 'engagement_average'
}
df7.rename(columns=column_mapping_7, inplace=True)
df7
# Out:
#      rank             name       instagram_name          category_1  \
# 0       1         leomessi            Leo Messi  Sports with a ball
# 1       2        cristiano    Cristiano Ronaldo  Sports with a ball
# 2       3         neymarjr                NJ 🇧🇷  Sports with a ball
# 3       4      kyliejenner              Kylie 🤍             Fashion
# 4       5    kendalljenner              Kendall            Modeling
# ..    ...              ...                  ...                 ...
# 995   996          thiago6     Thiago Alcantara  Sports with a ball
# 996   997  soycintiacossio        Cintia Cossio            Modeling
# 997   998        feat.dino                   이찬           Lifestyle
# 998   999       djokernole       Novak Djokovic  Sports with a ball
# 999  1000  ravindra.jadeja  Ravindrasinh jadeja           Lifestyle
#
#              category_2 subscribers audience_country eng._(auth.) eng._(avg.)
# ...

# %% [markdown]
# # Eight file to Clean

# %%
df8 = pd.read_csv("./Media_Data/social media influencers-instagram - -nov 2022.csv") 
df8
# Out:
#      s.no                    Name     Instagram Name  \
# 0       1               cristiano  Cristiano Ronaldo
# 1       2             kyliejenner            Kylie 🤍
# 2       3                leomessi          Leo Messi
# 3       4            arianagrande      Ariana Grande
# 4       5                 zendaya            Zendaya
# ..    ...                     ...                ...
# 995   996           thenewclassic        Iggy Azalea
# 996   997               min.nicha             MINNIE
# 997   998                francety      Francia James
# 998   999  silambarasantrofficial    Silambarasan TR
# 999  1000          lalala_lfamily            Lfamily
#
#                     Category-1 Followers      \nCountry Eng. (Auth.)  \
# 0           Sports with a ball    483.1M          India         4.5M
# 1                      Fashion      370M  United States         2.8M
# 2           Sports with a ball    357.8M      Indonesia         3.2M
# ...

# %%
df8.columns
# Out:
# Index(['s.no', 'Name', 'Instagram Name', 'Category-1', 'Followers',
#        '\nCountry', 'Eng. (Auth.)', 'Eng. (Avg.)', 'Category-2'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df8.columns = df8.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df8.columns = df8.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_8 = df8.select_dtypes(include='object').columns
for col in string_columns_8:
    df8[col] = df8[col].str.strip()

# Rename columns for potential consistency
column_mapping_8 = {
    'name': 'name',
    'instagram name': 'instagram_name',
    'category-1': 'category_1',
    'followers': 'subscribers',  # Assuming 'Followers' is the same as 'Subscribers'
    '\ncountry': 'audience_country',  # Assuming 'Country' refers to audience location and handling the newline
    'eng. (auth.)': 'authentic_engagement',
    'eng. (avg.)': 'engagement_average',
    'category-2': 'category_2'
}
df8.rename(columns=column_mapping_8, inplace=True)
df8
# Out:
#      s.no                    name     instagram_name  \
# 0       1               cristiano  Cristiano Ronaldo
# 1       2             kyliejenner            Kylie 🤍
# 2       3                leomessi          Leo Messi
# 3       4            arianagrande      Ariana Grande
# 4       5                 zendaya            Zendaya
# ..    ...                     ...                ...
# 995   996           thenewclassic        Iggy Azalea
# 996   997               min.nicha             MINNIE
# 997   998                francety      Francia James
# 998   999  silambarasantrofficial    Silambarasan TR
# 999  1000          lalala_lfamily            Lfamily
#
#                     category_1 subscribers        country eng._(auth.)  \
# 0           Sports with a ball      483.1M          India         4.5M
# 1                      Fashion        370M  United States         2.8M
# 2           Sports with a ball      357.8M      Indonesia         3.2M
# ...

# %% [markdown]
# # Ninth File to Clean

# %%
df9 = pd.read_csv("./Media_Data/social media influencers-instagram june 2022 - june 2022.csv") 
df9
# Out:
#           instagram name influencer name                  Category_1  \
# 0                    433              433         Sports with a ball
# 1          ____kimwoobin         김우빈                  Lifestyle
# 2           __youngbae__          TAEYANG                      Music
# 3            _agentgirl_    НАСТЯ ИВЛЕЕВА                      Shows
# 4          _hakkencoser_        Hakken 八犬                  Lifestyle
# ...                  ...              ...                        ...
# 1017              zidane           zidane         Sports with a ball
# 1018              zidane           zidane         Sports with a ball
# 1019              zkdlin              KAI                      Music
# 1020                  zo       Lonzo Ball         Sports with a ball
# 1021  zoeisabellakravitz     Zoë Kravitz  Cinema & Actors/actresses
#
#        Category_2 Subscribers count     Views avg. Likes avg Comments avg.
# ...

# %%
df9.columns
# Out:
# Index(['instagram name', 'influencer name ', 'Category_1', 'Category_2',
#        'Subscribers count', 'Views avg.', 'Likes avg', 'Comments avg.'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df9.columns = df9.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df9.columns = df9.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_9 = df9.select_dtypes(include='object').columns
for col in string_columns_9:
    df9[col] = df9[col].str.strip()

# Rename columns for potential consistency
column_mapping_9 = {
    'instagram name': 'instagram_name',
    'influencer name': 'influencer_name',  # Removed extra space
    'category_1': 'category_1',
    'category_2': 'category_2',
    'subscribers count': 'subscribers',  # Standardized name
    'views avg.': 'views_average',
    'likes avg': 'likes_average',   # Removed period for consistency
    'comments avg.': 'comments_average'
}
df9.rename(columns=column_mapping_9, inplace=True)
df9
# Out:
#           instagram_name influencer_name                 category_1  \
# 0                    433             433         Sports with a ball
# 1          ____kimwoobin        김우빈                  Lifestyle
# 2           __youngbae__         TAEYANG                      Music
# 3            _agentgirl_   НАСТЯ ИВЛЕЕВА                      Shows
# 4          _hakkencoser_       Hakken 八犬                  Lifestyle
# ...                  ...             ...                        ...
# 1017              zidane          zidane         Sports with a ball
# 1018              zidane          zidane         Sports with a ball
# 1019              zkdlin             KAI                      Music
# 1020                  zo      Lonzo Ball         Sports with a ball
# 1021  zoeisabellakravitz    Zoë Kravitz  Cinema & Actors/actresses
#
#        category_2 subscribers_count     views_avg. likes_avg comments_avg.
# 0             NaN             50.7M          Spain    274.9K        456.7K
# ...

# %% [markdown]
# # Tenth File to Clean

# %%
df10 = pd.read_csv("./Media_Data/social media influencers-TIKTOK - ---DEC 2022.csv") 
df10
# Out:
#      Rank Tiktoker name                     Tiktok name followers views(avg)  \
# 0       1       mrbeast                         MrBeast     60.3M      29.2M
# 1       2        karolg                         Karol G     42.4M      23.7M
# 2       3         yzn47                      يزن الأسمر      8.9M      48.9M
# 3       4    centralcee                      CentralCee      4.4M      19.8M
# 4       5      adinross                            adin      6.1M      21.1M
# ..    ...           ...                             ...       ...        ...
# 995   996   jiembasands                    Jiemba Sands      4.9M       3.4M
# 996   997    crissa_ace                  Crissa Jackson     14.9M       1.6M
# 997   998      ichadude                   Alyssa & Dude    468.8K       2.3M
# 998   999     kanebrown                      Kane Brown      5.2M       1.7M
# 999  1000      nnennab_  Nnenna B | NYC Creator & Actor    149.1K     606.2K
#
#     likes(avg.) comments(avg.) shares(avg.)
# ...

# %%
df10.columns
# Out:
# Index(['Rank', 'Tiktoker name', 'Tiktok name', 'followers', 'views(avg)',
#        'likes(avg.)', 'comments(avg.)', 'shares(avg.)'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df10.columns = df10.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df10.columns = df10.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_10 = df10.select_dtypes(include='object').columns
for col in string_columns_10:
    df10[col] = df10[col].str.strip()

# Rename columns for potential consistency
column_mapping_10 = {
    'tiktoker name': 'tiktoker_name',
    'tiktok name': 'tiktok_name',
    'followers': 'subscribers',  # Standardized name
    'views(avg)': 'views_average',  # Standardized format
    'likes(avg.)': 'likes_average',  # Standardized format
    'comments(avg.)': 'comments_average',  # Standardized format
    'shares(avg.)': 'shares_average'  # Standardized format
}
df10.rename(columns=column_mapping_10, inplace=True)
df10
# Out:
#      rank tiktoker_name                     tiktok_name subscribers  \
# 0       1       mrbeast                         MrBeast       60.3M
# 1       2        karolg                         Karol G       42.4M
# 2       3         yzn47                      يزن الأسمر        8.9M
# 3       4    centralcee                      CentralCee        4.4M
# 4       5      adinross                            adin        6.1M
# ..    ...           ...                             ...         ...
# 995   996   jiembasands                    Jiemba Sands        4.9M
# 996   997    crissa_ace                  Crissa Jackson       14.9M
# 997   998      ichadude                   Alyssa & Dude      468.8K
# 998   999     kanebrown                      Kane Brown        5.2M
# 999  1000      nnennab_  Nnenna B | NYC Creator & Actor      149.1K
#
#     views_average likes_average comments_average shares_average
# 0           29.2M          3.5M            30.8K           7.2K
# ...

# %% [markdown]
# # Eleventh File to Clean

# %%
df11 = pd.read_csv("./Media_Data/social media influencers-tiktok - ---nov 2022.csv") 
df11
# Out:
#       row-cell    Tiktoker name       Tiktok name \nFollowers Views (Avg.)  \
# 0          NaN              NaN               NaN         NaN          NaN
# 1          1.0      yossikramer             Yossi      145.6K        26.8M
# 2          2.0          mrbeast           MrBeast       55.6M        38.1M
# 3          3.0         adinross              adin        5.4M        16.6M
# 4          4.0   daniel.labelle    Daniel LaBelle       27.9M        11.8M
# ...        ...              ...               ...         ...          ...
# 996      996.0  nathanmccarron0      Nathan’s Art        1.6M         1.1M
# 997      997.0        lacha21.1   Lazaro Gonzalez      669.4K       750.3K
# 998      998.0          hyoga.x             Hyoga        552K           1M
# 999      999.0   rrqr7tatsumaki    Rivaldi Fataah        1.1M           2M
# 1000    1000.0         _catben_  Catherine Benson       10.9M         1.6M
#
#      Likes (Avg.) Comments (Avg.) Shares (Avg.)
# ...

# %%
df11.columns
# Out:
# Index(['row-cell', 'Tiktoker name', 'Tiktok name', '\nFollowers',
#        'Views (Avg.)', 'Likes (Avg.)', 'Comments (Avg.)', 'Shares (Avg.)'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df11.columns = df11.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df11.columns = df11.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_11 = df11.select_dtypes(include='object').columns
for col in string_columns_11:
    df11[col] = df11[col].str.strip()

# Rename columns for potential consistency
column_mapping_11 = {
    'tiktoker name': 'tiktoker_name',
    'tiktok name': 'tiktok_name',
    '\nfollowers': 'subscribers',  # Handling the newline
    'views (avg.)': 'views_average',
    'likes (avg.)': 'likes_average',
    'comments (avg.)': 'comments_average',
    'shares (avg.)': 'shares_average'
}
df11.rename(columns=column_mapping_11, inplace=True)
df11
# Out:
#       row-cell    tiktoker_name       tiktok_name followers views_(avg.)  \
# 0          NaN              NaN               NaN       NaN          NaN
# 1          1.0      yossikramer             Yossi    145.6K        26.8M
# 2          2.0          mrbeast           MrBeast     55.6M        38.1M
# 3          3.0         adinross              adin      5.4M        16.6M
# 4          4.0   daniel.labelle    Daniel LaBelle     27.9M        11.8M
# ...        ...              ...               ...       ...          ...
# 996      996.0  nathanmccarron0      Nathan’s Art      1.6M         1.1M
# 997      997.0        lacha21.1   Lazaro Gonzalez    669.4K       750.3K
# 998      998.0          hyoga.x             Hyoga      552K           1M
# 999      999.0   rrqr7tatsumaki    Rivaldi Fataah      1.1M           2M
# 1000    1000.0         _catben_  Catherine Benson     10.9M         1.6M
#
#      likes_(avg.) comments_(avg.) shares_(avg.)
# ...

# %% [markdown]
# # Twelfth File to Clean

# %%
df12 = pd.read_csv("./Media_Data/social media influencers-tiktok june 2022 - june 2022.csv") 
df12
# Out:
#               Tiktoker         influencer name Subscribers count Views avg.  \
# 0       ___nicoichi___           NICO【平成フラミンゴ】              1.3M       1.9M
# 1      _.anime.edits_0                   video               97K       1.7M
# 2     _.respect.boss._  Respect compilation 🤝🥶              1.5M       4.4M
# 3     _.the.meme.hub._            RANDOM MEMES              2.3M       3.8M
# 4       _andrewcurtiss           Andrew Curtis              2.5M       1.4M
# ...                ...                     ...               ...        ...
# 1002              zeth                    Zeth             12.5M       6.7M
# 1003  zodiac.boyfriend      Zodiac Boyfriend🪐🔮              1.8M       1.9M
# 1004       zowloficial               Lord Zowl              1.1M       1.4M
# 1005          zrt.foot                     ZR7            100.8K       2.3M
# 1006         zubarefff       Зубарев Александр                4M       1.9M
#
#      Likes avg Comments avg. Shares avg
# ...

# %%
df12.columns
# Out:
# Index(['Tiktoker', 'influencer name', 'Subscribers count', 'Views avg.',
#        'Likes avg', 'Comments avg.', 'Shares avg'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df12.columns = df12.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df12.columns = df12.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_12 = df12.select_dtypes(include='object').columns
for col in string_columns_12:
    df12[col] = df12[col].str.strip()

# Rename columns for potential consistency
column_mapping_12 = {
    'tiktoker': 'tiktoker_name',
    'influencer name': 'influencer_name',
    'subscribers count': 'subscribers',
    'views avg.': 'views_average',
    'likes avg': 'likes_average',
    'comments avg.': 'comments_average',
    'shares avg': 'shares_average'
}
df12.rename(columns=column_mapping_12, inplace=True)
df12
# Out:
#          tiktoker_name         influencer_name subscribers_count views_avg.  \
# 0       ___nicoichi___           NICO【平成フラミンゴ】              1.3M       1.9M
# 1      _.anime.edits_0                   video               97K       1.7M
# 2     _.respect.boss._  Respect compilation 🤝🥶              1.5M       4.4M
# 3     _.the.meme.hub._            RANDOM MEMES              2.3M       3.8M
# 4       _andrewcurtiss           Andrew Curtis              2.5M       1.4M
# ...                ...                     ...               ...        ...
# 1002              zeth                    Zeth             12.5M       6.7M
# 1003  zodiac.boyfriend      Zodiac Boyfriend🪐🔮              1.8M       1.9M
# 1004       zowloficial               Lord Zowl              1.1M       1.4M
# 1005          zrt.foot                     ZR7            100.8K       2.3M
# 1006         zubarefff       Зубарев Александр                4M       1.9M
#
#      likes_avg comments_avg. shares_avg
# ...

# %% [markdown]
# # Thirteenth File to Clean

# %%
df13 = pd.read_csv("./Media_Data/social media influencers-YOUTUBE - --DEC 2022.csv") 
df13
# Out:
#       s.no            Youtube channel               youtuber name  \
# 0        1                    tseries                    T-Series
# 1        2                   setindia                   SET India
# 2        3                  checkgate  Cocomelon - Nursery Rhymes
# 3        4                    MrBeast                     MrBeast
# 4        5                  PewDiePie                   PewDiePie
# ...    ...                        ...                         ...
# 998    999              ClassicMrBean             Classic Mr Bean
# 999   1000         Anupam Movie Songs          Anupam Movie Songs
# 1000   970                 AnandAudio                 Anand Audio
# 1001   971                   Wylsacom                    Wylsacom
# 1002   986  Eagle Home Entertainments   Eagle Home Entertainments
#
#                   Category Followers        Country \nViews (Avg.)  \
# 0            Music & Dance    229.5M          India         103.8K
# ...

# %%
df13.columns
# Out:
# Index(['s.no', 'Youtube channel', 'youtuber name', 'Category', 'Followers',
#        'Country', '\nViews (Avg.)', 'Likes (Avg.)', 'Comments (Avg.)',
#        'Category-2'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df13.columns = df13.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df13.columns = df13.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_13 = df13.select_dtypes(include='object').columns
for col in string_columns_13:
    df13[col] = df13[col].str.strip()

# Rename columns for potential consistency
column_mapping_13 = {
    'youtube channel': 'youtube_channel_name',
    'youtuber name': 'youtuber_name',
    'category': 'category_1',  # Consistent with other files
    'followers': 'subscribers',
    '\ncountry': 'audience_country',  # Handling the newline
    'views (avg.)': 'views_average',
    'likes (avg.)': 'likes_average',
    'comments (avg.)': 'comments_average',
    'category_2': 'category_2'
}
df13.rename(columns=column_mapping_13, inplace=True)
df13
# Out:
#       s.no            youtube_channel               youtuber_name  \
# 0        1                    tseries                    T-Series
# 1        2                   setindia                   SET India
# 2        3                  checkgate  Cocomelon - Nursery Rhymes
# 3        4                    MrBeast                     MrBeast
# 4        5                  PewDiePie                   PewDiePie
# ...    ...                        ...                         ...
# 998    999              ClassicMrBean             Classic Mr Bean
# 999   1000         Anupam Movie Songs          Anupam Movie Songs
# 1000   970                 AnandAudio                 Anand Audio
# 1001   971                   Wylsacom                    Wylsacom
# 1002   986  Eagle Home Entertainments   Eagle Home Entertainments
#
#                 category_1 subscribers        country views_(avg.)  \
# 0            Music & Dance      229.5M          India       103.8K
# ...

# %% [markdown]
# # Fourteenth File to Clean

# %%
df14 = pd.read_csv("./Media_Data/social media influencers-youtube - --nov 2022.csv") 
df14
# Out:
#      s.no    Youtube channel               youtuber name         Category  \
# 0       1            tseries                    T-Series    Music & Dance
# 1       2          checkgate  Cocomelon - Nursery Rhymes        Education
# 2       3          PewDiePie                   PewDiePie        Animation
# 3       4        MrBeast6000                     MrBeast      Video games
# 4       5  ✿ Kids Diana Show           ✿ Kids Diana Show        Animation
# ..    ...                ...                         ...              ...
# 995   996               RUOK                        RUOK              NaN
# 996   997     FoxNewsChannel                    Fox News  News & Politics
# 997   998   SULE PRODUCTIONS            SULE PRODUCTIONS              NaN
# 998   999            MBCkpop                     MBCkpop    Music & Dance
# 999  1000      Dynamo Gaming               Dynamo Gaming              NaN
#
#     Followers        Country \nViews (Avg.) Likes (Avg.) Comments (Avg.)  \
# ...

# %%
df14.columns
# Out:
# Index(['s.no', 'Youtube channel', 'youtuber name', 'Category', 'Followers',
#        'Country', '\nViews (Avg.)', 'Likes (Avg.)', 'Comments (Avg.)',
#        'Category-2'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df14.columns = df14.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df14.columns = df14.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_14 = df14.select_dtypes(include='object').columns
for col in string_columns_14:
    df14[col] = df14[col].str.strip()

# Rename columns for potential consistency
column_mapping_14 = {
    'youtube channel': 'youtube_channel_name',
    'youtuber name': 'youtuber_name',
    'category': 'category_1',  # Consistent with other files
    'followers': 'subscribers',
    '\ncountry': 'audience_country',  # Handling the newline
    'views (avg.)': 'views_average',
    'likes (avg.)': 'likes_average',
    'comments (avg.)': 'comments_average',
    'category_2': 'category_2'
}
df14.rename(columns=column_mapping_14, inplace=True)
df14
# Out:
#      s.no    youtube_channel               youtuber_name       category_1  \
# 0       1            tseries                    T-Series    Music & Dance
# 1       2          checkgate  Cocomelon - Nursery Rhymes        Education
# 2       3          PewDiePie                   PewDiePie        Animation
# 3       4        MrBeast6000                     MrBeast      Video games
# 4       5  ✿ Kids Diana Show           ✿ Kids Diana Show        Animation
# ..    ...                ...                         ...              ...
# 995   996               RUOK                        RUOK              NaN
# 996   997     FoxNewsChannel                    Fox News  News & Politics
# 997   998   SULE PRODUCTIONS            SULE PRODUCTIONS              NaN
# 998   999            MBCkpop                     MBCkpop    Music & Dance
# 999  1000      Dynamo Gaming               Dynamo Gaming              NaN
#
#     subscribers        country views_(avg.) likes_(avg.) comments_(avg.)  \
# ...

# %% [markdown]
# # Fifteenth File to Clean

# %%
df15 = pd.read_csv("./Media_Data/social media influencers-youtube june 2022 - june 2022.csv") 
df15
# Out:
#                                     channel name  \
# 0                                        juptube
# 1     Baby Big Mouth Kids - Sing, Dance, Explore
# 2                                shfa show India
# 3           Blippi - Educational Videos for Kids
# 4                                 infobellstamil
# ...                                          ...
# 1016                                Power Vision
# 1017                                 POPSVIETNAM
# 1018                               Niki and Gabi
# 1019                                    Corridor
# 1020                                     JoshDub
#
#                                         youTuber       Category Category_2  \
# 0                             Galinha Pintadinha  Music & Dance        NaN
# 1     Baby Big Mouth Kids - Sing, Dance, Explore      Animation       Toys
# 2                                shfa show India    Daily vlogs        NaN
# ...

# %%
df15.columns
# Out:
# Index(['channel name', 'youTuber', 'Category', 'Category_2',
#        'Subscribers count', 'Country', 'Views avg.', 'Likes avg',
#        'Comments avg.'],
#       dtype='object')

# %%
# 1. Remove leading/trailing whitespace from column names
df15.columns = df15.columns.str.strip()

# 2. Standardize column names (lowercase and replace spaces with underscores)
df15.columns = df15.columns.str.lower().str.replace(' ', '_')

# 3. Clean string columns (if any) - assuming potential whitespace
string_columns_15 = df15.select_dtypes(include='object').columns
for col in string_columns_15:
    df15[col] = df15[col].str.strip()

# Rename columns for potential consistency
column_mapping_15 = {
    'channel name': 'youtube_channel_name',
    'youtuber': 'youtuber_name',
    'category': 'category_1',  # Consistent with other files
    'category_2': 'category_2',
    'subscribers count': 'subscribers',
    'country': 'audience_country',  # Assuming 'Country' refers to audience
    'views avg.': 'views_average',
    'likes avg': 'likes_average',
    'comments avg.': 'comments_average'
}
df15.rename(columns=column_mapping_15, inplace=True)
df15
# Out:
#                                     channel_name  \
# 0                                        juptube
# 1     Baby Big Mouth Kids - Sing, Dance, Explore
# 2                                shfa show India
# 3           Blippi - Educational Videos for Kids
# 4                                 infobellstamil
# ...                                          ...
# 1016                                Power Vision
# 1017                                 POPSVIETNAM
# 1018                               Niki and Gabi
# 1019                                    Corridor
# 1020                                     JoshDub
#
#                                    youtuber_name     category_1 category_2  \
# 0                             Galinha Pintadinha  Music & Dance        NaN
# 1     Baby Big Mouth Kids - Sing, Dance, Explore      Animation       Toys
# 2                                shfa show India    Daily vlogs        NaN
# ...

# %%
dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]

# Dictionary to store DataFrames for each platform
platform_data = {'instagram': [], 'tiktok': [], 'youtube': []}

# List of file names (for identification)
file_names = [
    'social media influencers - instagram sep-2022',
    'social media influencers - instagram',
    'social media influencers - Tiktok sep 2022',
    'social media influencers - tiktok',
    'social media influencers - Youtube sep-2022',
    'social media influencers - youtube',
    'social media influencers-INSTAGRAM - -DEC 2022',
    'social media influencers-instagram - -nov 2022',
    'social media influencers-instagram june 2022 - june 2022',
    'social media influencers-TIKTOK - ---DEC 2022',
    'social media influencers-tiktok - ---nov 2022',
    'social media influencers-tiktok june 2022 - june 2022',
    'social media influencers-YOUTUBE - --DEC 2022',
    'social media influencers-youtube - --nov 2022',
    'social media influencers-youtube june 2022 - june 2022'
]

# Categorize DataFrames by platform
for i, file_name in enumerate(file_names):
    if 'instagram' in file_name.lower():
        platform_data['instagram'].append(dfs[i])
    elif 'tiktok' in file_name.lower():
        platform_data['tiktok'].append(dfs[i])
    elif 'youtube' in file_name.lower():
        platform_data['youtube'].append(dfs[i])
    else:
        print(f"Warning: '{file_name}' not clearly identified.")

# %%
# Merge the DataFrames for each platform
merged_instagram_df = pd.concat(platform_data['instagram'], ignore_index=True) if platform_data['instagram'] else None
merged_tiktok_df = pd.concat(platform_data['tiktok'], ignore_index=True) if platform_data['tiktok'] else None
merged_youtube_df = pd.concat(platform_data['youtube'], ignore_index=True) if platform_data['youtube'] else None

# %%
# Print the shapes of the merged DataFrames
if merged_instagram_df is not None:
    print(f"\nShape of merged Instagram DataFrame: {merged_instagram_df.shape}")
    print(f"First few rows of merged Instagram data:\n{merged_instagram_df.head()}")
# Out:
# Shape of merged Instagram DataFrame: (5072, 21)
# First few rows of merged Instagram data:
#    s.no instagram_name               name subscribers audience_country  \
# 0   1.0      cristiano  Cristiano Ronaldo      477.9M            India
# 1   2.0    kyliejenner            Kylie 🤍      368.1M    United States
# 2   3.0   arianagrande      Ariana Grande      329.6M    United States
# 3   4.0       leomessi          Leo Messi      358.6M        Indonesia
# 4   5.0        zendaya            Zendaya      151.1M    United States
#
#   authentic_engagement engagement_average                 category_1  \
# 0                   5M               6.2M         Sports with a ball
# 1                 3.5M               5.5M                    Fashion
# 2                 2.9M                 4M                        NaN
# 3                 2.7M               3.5M         Sports with a ball
# 4                 4.3M               5.8M  Cinema & Actors/actresses
#
# ...

# %%
if merged_tiktok_df is not None:
    print(f"\nShape of merged TikTok DataFrame: {merged_tiktok_df.shape}")
    print(f"First few rows of merged TikTok data:\n{merged_tiktok_df.head()}")
# Out:
# Shape of merged TikTok DataFrame: (5008, 23)
# First few rows of merged TikTok data:
#    s.no   tiktoker_name   tiktok_name subscribers views_avg. likes_avg.  \
# 0   1.0   jypestraykids    Stray Kids       13.8M       6.4M       2.3M
# 1   2.0      khaby.lame  Khabane lame      149.2M      17.3M       2.3M
# 2   3.0  scarlettsspam2      scarlett        2.1M      17.9M     845.8K
# 3   4.0       addisonre   Addison Rae       88.7M        22M     906.6K
# 4   5.0      belindatok       Belinda        4.8M      14.2M       1.5M
#
#   comments_avg. shares_avg. subscribers_count likes_avg  ... likes_average  \
# 0         50.2K       34.2K               NaN       NaN  ...           NaN
# 1         15.2K        8.7K               NaN       NaN  ...           NaN
# 2         53.9K        6.3K               NaN       NaN  ...           NaN
# 3          7.6K       26.2K               NaN       NaN  ...           NaN
# ...

# %%
if merged_youtube_df is not None:
    print(f"\nShape of merged YouTube DataFrame: {merged_youtube_df.shape}")
    print(f"First few rows of merged YouTube data:\n{merged_youtube_df.head()}")
# Out:
# Shape of merged YouTube DataFrame: (5071, 24)
# First few rows of merged YouTube data:
#    s.no                        name      youtuber_name audience_country  \
# 0   1.0                    T-Series            tseries            India
# 1   2.0  Cocomelon - Nursery Rhymes          checkgate              NaN
# 2   3.0                   PewDiePie          PewDiePie    United States
# 3   4.0                     MrBeast        MrBeast6000    United States
# 4   5.0           ✿ Kids Diana Show  ✿ Kids Diana Show              NaN
#
#   subscribers     category_2 avg._views avg._likes avg_comments category_3  \
# 0      224.4M  Music & Dance     141.5K       4.6K          125        NaN
# 1      142.5M      Education      12.5M      64.8K            0        NaN
# 2      111.6M      Animation       1.9M     130.5K         7.4K        NaN
# 3      104.1M    Video games      44.8M       2.2M        70.9K      Humor
# ...

# %%
merged_instagram_df.columns
# Out:
# Index(['s.no', 'instagram_name', 'name', 'subscribers', 'audience_country',
#        'authentic_engagement', 'engagement_average', 'category_1',
#        'category_2', 'influencer_insta_name', 'audience_country(mostly)',
#        'engagement_avg', 'rank', 'eng._(auth.)', 'eng._(avg.)', 'country',
#        'influencer_name', 'subscribers_count', 'views_avg.', 'likes_avg',
#        'comments_avg.'],
#       dtype='object')

# %%
merged_tiktok_df.columns
# Out:
# Index(['s.no', 'tiktoker_name', 'tiktok_name', 'subscribers', 'views_avg.',
#        'likes_avg.', 'comments_avg.', 'shares_avg.', 'subscribers_count',
#        'likes_avg', 'shares_avg', 'rank', 'views_average', 'likes_average',
#        'comments_average', 'shares_average', 'row-cell', 'followers',
#        'views_(avg.)', 'likes_(avg.)', 'comments_(avg.)', 'shares_(avg.)',
#        'influencer_name'],
#       dtype='object')

# %%
merged_youtube_df.columns
# Out:
# Index(['s.no', 'name', 'youtuber_name', 'audience_country', 'subscribers',
#        'category_2', 'avg._views', 'avg._likes', 'avg_comments', 'category_3',
#        'channel_name', 'category', 'avg_views', 'avg_likes', 'youtube_channel',
#        'category_1', 'country', 'views_(avg.)', 'likes_(avg.)',
#        'comments_(avg.)', 'subscribers_count', 'views_avg.', 'likes_avg',
#        'comments_avg.'],
#       dtype='object')

# %%
# 1. Standardize Column Names (already done in previous cleaning)
# Ensure all column names are consistent (lowercase, underscores)
merged_instagram_df.columns = merged_instagram_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('.', '')
# Out:
# C:\Users\lualg\AppData\Local\Temp\ipykernel_30896\1167693871.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   merged_instagram_df.columns = merged_instagram_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('.', '')

# %%
# 2. Identify and Handle Duplicate Columns
# Create a set of unique column names
unique_cols_insta = set()
duplicate_cols_insta = []
for col in merged_instagram_df.columns:
    if col in unique_cols_insta:
        duplicate_cols_insta.append(col)
    else:
        unique_cols_insta.add(col)

if duplicate_cols_insta:
    print(f"Duplicate columns found in merged_instagram_df: {duplicate_cols_insta}")
    # You might want to inspect these and decide how to handle them.
    # For now, let's keep the first occurrence.
    merged_instagram_df = merged_instagram_df.loc[:, ~merged_instagram_df.columns.duplicated()]
    print(f"Shape after removing duplicate columns: {merged_instagram_df.shape}")

# %%
# 3. Handle Missing Values (NaN)
print(f"\nMissing values before handling:")
print(merged_instagram_df.isnull().sum().sort_values(ascending=False).head())

# Decide on a strategy for missing values. Options include:
# - Imputation (filling with mean, median, mode, or more advanced techniques)
# - Dropping rows with any NaN
# - Dropping columns with too many NaNs
# For now, let's drop rows where key identifier (e.g., instagram_name) is missing
merged_instagram_df.dropna(subset=['instagram_name'], inplace=True)
merged_instagram_df.fillna({'category_1': 'Unknown', 'category_2': 'Unknown'}, inplace=True) # Fill categorical NaNs
# For numerical columns, you might impute or drop based on context
numeric_cols_insta = merged_instagram_df.select_dtypes(include=['number']).columns
for col in numeric_cols_insta:
    if merged_instagram_df[col].isnull().sum() > 0:
        # Example imputation with median (can be replaced with other strategies)
        median_val = merged_instagram_df[col].median()
        merged_instagram_df[col].fillna(median_val, inplace=True)
        print(f"Filled missing values in '{col}' with median: {median_val}")

print(f"Missing values after handling:")
print(merged_instagram_df.isnull().sum().sort_values(ascending=False).head())
print(f"Shape after handling missing values: {merged_instagram_df.shape}")
# Out:
# Missing values before handling:
# audience_country(mostly)    4086
# influencer_name             4076
# country                     4076
# influencer_insta_name       4072
# rank                        4072
# dtype: int64
# Filled missing values in 'sno' with median: 512.5
# Filled missing values in 'rank' with median: 499.0
# Missing values after handling:
# audience_country(mostly)    4045
# country                     4036
# influencer_insta_name       4031
# engagement_avg              4031
# influencer_name             4014
# dtype: int64
# Shape after handling missing values: (5010, 21)

# %%
# 4. Handle Duplicate Rows
initial_rows_insta = merged_instagram_df.shape[0]
merged_instagram_df.drop_duplicates(inplace=True)
rows_dropped_insta = initial_rows_insta - merged_instagram_df.shape[0]
if rows_dropped_insta > 0:
    print(f"\nDropped {rows_dropped_insta} duplicate rows.")
else:
    print("\nNo duplicate rows found.")
print(f"Shape after dropping duplicate rows: {merged_instagram_df.shape}")
# Out:
# Dropped 77 duplicate rows.
# Shape after dropping duplicate rows: (4933, 21)

# %%
# 5. Data Type Conversion (if needed)
# Example: Convert subscriber counts to integer
if 'subscribers' in merged_instagram_df.columns:
    merged_instagram_df['subscribers'] = pd.to_numeric(merged_instagram_df['subscribers'], errors='coerce').fillna(0).astype('int64')

# %%
print(f"\nFinal shape of cleaned merged_instagram_df: {merged_instagram_df.shape}")
merged_instagram_df
# Out:
# Final shape of cleaned merged_instagram_df: (4933, 21)
#         sno      instagram_name               name  subscribers  \
# 0       1.0           cristiano  Cristiano Ronaldo            0
# 1       2.0         kyliejenner            Kylie 🤍            0
# 2       3.0        arianagrande      Ariana Grande            0
# 3       4.0            leomessi          Leo Messi            0
# 4       5.0             zendaya            Zendaya            0
# ...     ...                 ...                ...          ...
# 5066  512.5             zendaya                NaN            0
# 5067  512.5              zidane                NaN            0
# 5069  512.5              zkdlin                NaN            0
# 5070  512.5                  zo                NaN            0
# 5071  512.5  zoeisabellakravitz                NaN            0
#
#      audience_country authentic_engagement engagement_average  \
# 0               India                   5M               6.2M
# ...

# %%
# 1. Standardize Column Names
merged_tiktok_df.columns = merged_tiktok_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('.', '').str.replace('\n', '')
# Out:
# C:\Users\lualg\AppData\Local\Temp\ipykernel_30896\3839447210.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   merged_tiktok_df.columns = merged_tiktok_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('.', '').str.replace('\n', '')

# %%
# 2. Identify and Handle Duplicate Columns
unique_cols_tiktok = set()
duplicate_cols_tiktok = []
for col in merged_tiktok_df.columns:
    if col in unique_cols_tiktok:
        duplicate_cols_tiktok.append(col)
    else:
        unique_cols_tiktok.add(col)

if duplicate_cols_tiktok:
    print(f"Duplicate columns found in merged_tiktok_df: {duplicate_cols_tiktok}")
    merged_tiktok_df = merged_tiktok_df.loc[:, ~merged_tiktok_df.columns.duplicated()]
    print(f"Shape after removing duplicate columns: {merged_tiktok_df.shape}")
# Out:
# Duplicate columns found in merged_tiktok_df: ['likes_avg', 'shares_avg']
# Shape after removing duplicate columns: (5008, 21)

# %%
# 3. Handle Missing Values (NaN)
print(f"\nMissing values before handling:")
print(merged_tiktok_df.isnull().sum().sort_values(ascending=False).head())

merged_tiktok_df.dropna(subset=['tiktoker_name', 'tiktok_name'], inplace=True)
merged_tiktok_df.fillna({'influencer_name': 'Unknown'}, inplace=True)
numeric_cols_tiktok = merged_tiktok_df.select_dtypes(include=['number']).columns
for col in numeric_cols_tiktok:
    if merged_tiktok_df[col].isnull().sum() > 0:
        median_val = merged_tiktok_df[col].median()
        merged_tiktok_df[col].fillna(median_val, inplace=True)
        print(f"Filled missing values in '{col}' with median: {median_val}")

print(f"Missing values after handling:")
print(merged_tiktok_df.isnull().sum().sort_values(ascending=False).head())
print(f"Shape after handling missing values: {merged_tiktok_df.shape}")
# Out:
# Missing values before handling:
# sno               4008
# likes_average     4008
# shares_(avg)      4008
# comments_(avg)    4008
# likes_(avg)       4008
# dtype: int64
# Filled missing values in 'sno' with median: 500.0
# Filled missing values in 'rank' with median: 500.5
# Filled missing values in 'row-cell' with median: 500.5
# Missing values after handling:
# subscribers_count    2999
# likes_avg            2998
# shares_avg           2998
# views_average        2997
# followers            2997
# dtype: int64
# Shape after handling missing values: (3997, 21)

# %%
# 4. Handle Duplicate Rows
initial_rows_tiktok = merged_tiktok_df.shape[0]
merged_tiktok_df.drop_duplicates(inplace=True)
rows_dropped_tiktok = initial_rows_tiktok - merged_tiktok_df.shape[0]
if rows_dropped_tiktok > 0:
    print(f"\nDropped {rows_dropped_tiktok} duplicate rows.")
else:
    print("\nNo duplicate rows found.")
print(f"Shape after dropping duplicate rows: {merged_tiktok_df.shape}")
# Out:
# Dropped 11 duplicate rows.
# Shape after dropping duplicate rows: (3986, 21)

# %%
# 5. Data Type Conversion
if 'subscribers' in merged_tiktok_df.columns:
    merged_tiktok_df['subscribers'] = pd.to_numeric(merged_tiktok_df['subscribers'], errors='coerce').fillna(0).astype('int64')
# Convert average columns to numeric
avg_cols_tiktok = [col for col in merged_tiktok_df.columns if 'avg' in col]
for col in avg_cols_tiktok:
    merged_tiktok_df[col] = pd.to_numeric(merged_tiktok_df[col], errors='coerce').fillna(0)

# %%
print(f"\nFinal shape of cleaned merged_tiktok_df: {merged_tiktok_df.shape}")
merged_tiktok_df
# Out:
# Final shape of cleaned merged_tiktok_df: (3986, 21)
#         sno    tiktoker_name       tiktok_name  subscribers  views_avg  \
# 0       1.0    jypestraykids        Stray Kids            0        0.0
# 1       2.0       khaby.lame      Khabane lame            0        0.0
# 2       3.0   scarlettsspam2          scarlett            0        0.0
# 3       4.0        addisonre       Addison Rae            0        0.0
# 4       5.0       belindatok           Belinda            0        0.0
# ...     ...              ...               ...          ...        ...
# 3996  500.0  nathanmccarron0      Nathan’s Art            0        0.0
# 3997  500.0        lacha21.1   Lazaro Gonzalez            0        0.0
# 3998  500.0          hyoga.x             Hyoga            0        0.0
# 3999  500.0   rrqr7tatsumaki    Rivaldi Fataah            0        0.0
# 4000  500.0         _catben_  Catherine Benson            0        0.0
#
# ...

# %%
# 1. Standardize Column Names
merged_youtube_df.columns = merged_youtube_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('.', '').str.replace('\n', '')
# Out:
# C:\Users\lualg\AppData\Local\Temp\ipykernel_30896\1375985810.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   merged_youtube_df.columns = merged_youtube_df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('.', '').str.replace('\n', '')

# %%
# 2. Identify and Handle Duplicate Columns
unique_cols_youtube = set()
duplicate_cols_youtube = []
for col in merged_youtube_df.columns:
    if col in unique_cols_youtube:
        duplicate_cols_youtube.append(col)
    else:
        unique_cols_youtube.add(col)

if duplicate_cols_youtube:
    print(f"Duplicate columns found in merged_youtube_df: {duplicate_cols_youtube}")
    merged_youtube_df = merged_youtube_df.loc[:, ~merged_youtube_df.columns.duplicated()]
    print(f"Shape after removing duplicate columns: {merged_youtube_df.shape}")
# Out:
# Duplicate columns found in merged_youtube_df: ['avg_views', 'avg_likes']
# Shape after removing duplicate columns: (5071, 22)

# %%
# 3. Handle Missing Values (NaN)
print(f"\nMissing values before handling:")
print(merged_youtube_df.isnull().sum().sort_values(ascending=False).head())

merged_youtube_df.dropna(subset=['youtuber_name', 'youtube_channel'], inplace=True)
merged_youtube_df.fillna({'category_1': 'Unknown', 'category_2': 'Unknown', 'category_3': 'Unknown', 'audience_country': 'Unknown'}, inplace=True)
numeric_cols_youtube = merged_youtube_df.select_dtypes(include=['number']).columns
for col in numeric_cols_youtube:
    if merged_youtube_df[col].isnull().sum() > 0:
        median_val = merged_youtube_df[col].median()
        merged_youtube_df[col].fillna(median_val, inplace=True)
        print(f"Filled missing values in '{col}' with median: {median_val}")

print(f"Missing values after handling:")
print(merged_youtube_df.isnull().sum().sort_values(ascending=False).head())
print(f"Shape after handling missing values: {merged_youtube_df.shape}")
# Out:
# Missing values before handling:
# category_3           4791
# category             4348
# likes_avg            4050
# views_avg            4050
# subscribers_count    4050
# dtype: int64
# Missing values after handling:
# category             2003
# avg_comments         2003
# likes_avg            2003
# views_avg            2003
# subscribers_count    2003
# dtype: int64
# Shape after handling missing values: (2003, 22)

# %%
# 4. Handle Duplicate Rows
initial_rows_youtube = merged_youtube_df.shape[0]
merged_youtube_df.drop_duplicates(inplace=True)
rows_dropped_youtube = initial_rows_youtube - merged_youtube_df.shape[0]
if rows_dropped_youtube > 0:
    print(f"\nDropped {rows_dropped_youtube} duplicate rows.")
else:
    print("\nNo duplicate rows found.")
print(f"Shape after dropping duplicate rows: {merged_youtube_df.shape}")
# Out:
# Dropped 31 duplicate rows.
# Shape after dropping duplicate rows: (1972, 22)

# %%
# 5. Data Type Conversion
if 'subscribers' in merged_youtube_df.columns:
    merged_youtube_df['subscribers'] = pd.to_numeric(merged_youtube_df['subscribers'], errors='coerce').fillna(0).astype('int64')
avg_cols_youtube = [col for col in merged_youtube_df.columns if 'avg' in col]
for col in avg_cols_youtube:
    merged_youtube_df[col] = pd.to_numeric(merged_youtube_df[col], errors='coerce').fillna(0)

# %%
print(f"\nFinal shape of cleaned merged_youtube_df: {merged_youtube_df.shape}")
merged_youtube_df
# Out:
# Final shape of cleaned merged_youtube_df: (1972, 22)
#          sno name               youtuber_name audience_country  subscribers  \
# 2047     1.0  NaN                    T-Series          Unknown            0
# 2048     2.0  NaN                   SET India          Unknown            0
# 2049     3.0  NaN  Cocomelon - Nursery Rhymes          Unknown            0
# 2050     4.0  NaN                     MrBeast          Unknown            0
# 2051     5.0  NaN                   PewDiePie          Unknown            0
# ...      ...  ...                         ...              ...          ...
# 4045   996.0  NaN                        RUOK          Unknown            0
# 4046   997.0  NaN                    Fox News          Unknown            0
# 4047   998.0  NaN            SULE PRODUCTIONS          Unknown            0
# 4048   999.0  NaN                     MBCkpop          Unknown            0
# 4049  1000.0  NaN               Dynamo Gaming          Unknown            0
#
# ...

# %%
# --- Save merged_instagram_df to CSV ---
merged_instagram_df.to_csv('./Clean_Data/merged_instagram_data_cleaned.csv', index=False, encoding='utf-8')

# --- Save merged_tiktok_df to CSV ---
merged_tiktok_df.to_csv('./Clean_Data/merged_tiktok_data_cleaned.csv', index=False, encoding='utf-8')

# --- Save merged_youtube_df to CSV ---
merged_youtube_df.to_csv('./Clean_Data/merged_youtube_data_cleaned.csv', index=False, encoding='utf-8')
